# %%
#import all libraries

# numpy and pandas help us load and manipulate data
import numpy as np
import pandas as pd

# matplotlib and seaborn are used to plot data
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from statsmodels.formula.api import ols

#sklearn has many machine learning algorithms
from sklearn.linear_model import LinearRegression

# this helps split data for modeling
from sklearn.model_selection import train_test_split

import scipy as sp
import statsmodels.stats.diagnostic as diag
from statsmodels.stats.diagnostic import het_breuschpagan

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import statsmodels.api as sms
import pysal

import statsmodels.tsa.api as smt
from statsmodels.compat import lzip
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
# Load Student Performance Data
student1=pd.read_csv("student-mat.csv",sep=';',header=0)
student2=pd.read_csv("student-por.csv",sep=';',header=0)
students=pd.concat([student1,student2])

#Drop protected column
students = students.drop(['school','sex','age','address',],axis=1)

#create a dummy variable for categorical columns
df = pd.get_dummies(students, columns=['Pstatus','famsize','Mjob', 'Fjob', 'reason', 'guardian', 'famsup', 'paid', 'activities', 'schoolsup', 'nursery','higher','internet', 'romantic'])

print(df)

#Split Data
X = df.iloc[:, : -1]
y = df['G3']

# Create Training and testing sets

# Your code goes here


# Create Linear Regression (OLS)
y = df.G3  
X = df.G2  
X = sms.add_constant(X)  

est=sms.OLS(y, X)
est = est.fit()
print('Model Degree of Freedom:', est.df_model)
print('Residual Degree of Freedom:', est.df_resid)
est.summary()
# Out:
#      Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0       4     4           2          2         0       4         3      4
# 1       1     1           1          2         0       5         3      3
# 2       1     1           1          2         3       4         3      2
# 3       4     2           1          3         0       3         2      2
# 4       3     3           1          2         0       4         3      2
# ..    ...   ...         ...        ...       ...     ...       ...    ...
# 644     2     3           1          3         1       5         4      2
# 645     3     1           1          2         0       4         3      4
# 646     1     1           2          2         0       1         1      1
# 647     3     1           2          1         0       2         4      5
# 648     3     2           3          1         0       4         4      1
#
#      Dalc  Walc  ...  schoolsup_no  schoolsup_yes  nursery_no  nursery_yes  \
# 0       1     1  ...         False           True       False         True
# 1       1     1  ...          True          False        True        False
# 2       2     3  ...         False           True       False         True
# 3       1     1  ...          True          False       False         True
# 4       1     2  ...          True          False       False         True
# ..    ...   ...  ...           ...            ...         ...          ...
# 644     1     2  ...          True          False        True        False
# 645     1     1  ...          True          False       False         True
# 646     1     1  ...          True          False       False         True
# 647     3     4  ...          True          False        True        False
# 648     3     4  ...          True          False        True        False
#
#      higher_no  higher_yes  internet_no  internet_yes  romantic_no  \
# 0        False        True         True         False         True
# 1        False        True        False          True         True
# 2        False        True        False          True         True
# 3        False        True        False          True        False
# 4        False        True         True         False         True
# ..         ...         ...          ...           ...          ...
# 644      False        True        False          True         True
# 645      False        True        False          True         True
# 646      False        True         True         False         True
# 647      False        True        False          True         True
# 648      False        True        False          True         True
#
#      romantic_yes
# 0           False
# 1           False
# 2           False
# 3            True
# 4           False
# ..            ...
# 644         False
# 645         False
# 646         False
# 647         False
# 648         False
#
# [1044 rows x 52 columns]
# Model Degree of Freedom: 1.0
# Residual Degree of Freedom: 1042.0
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.829
# Method:                 Least Squares   F-statistic:                     5068.
# Date:                Sat, 26 Aug 2023   Prob (F-statistic):               0.00
# Time:                        23:57:03   Log-Likelihood:                -1969.0
# No. Observations:                1044   AIC:                             3942.
# Df Residuals:                    1042   BIC:                             3952.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7079      0.176     -4.015      0.000      -1.054      -0.362
# G2             1.0715      0.015     71.188      0.000       1.042       1.101
# ==============================================================================
# Omnibus:                      714.254   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10032.938
# Skew:                          -3.010   Prob(JB):                         0.00
# Kurtosis:                      16.943   Cond. No.                         42.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10452\2323806862.py in ?()
# ----> 1 df.reason
#
# c:\Users\Rabin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reason'
